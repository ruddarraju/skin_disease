# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvan588/Skin-Disease-Prediction/blob/main/Skin_Disease_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Downloading the dataset

# %%
# !kaggle datasets download -d subirbiswas19/skin-disease-dataset
# Out:
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from zipfile import ZipFile

with ZipFile("skin-disease-dataset.zip", "r") as zip_ref:
  zip_ref.extractall()

# %% [markdown]
# Checking no of images

# %%
import os
train_dir = r"C:\Users\abhil\Desktop\skin disease\skin-disease-datasaet\train_set"
total_train_images  =0

for category in os.listdir(train_dir):
    category_dir = os.path.join(train_dir, category)
    num_images = len(os.listdir(category_dir))
    total_train_images += num_images

print("Total no of training images: ", total_train_images)
# Out:
# Total no of training images:  925

# %%
test_dir = r"C:\Users\abhil\Desktop\skin disease\skin-disease-datasaet\test_set"
total_test_images  =0

for category in os.listdir(test_dir):
  category_dir = os.path.join(test_dir , category)
  num_images = len(os.listdir(category_dir))
  total_test_images += num_images

print("Total no of test images: ", total_test_images)
# Out:
# Total no of test images:  234

# %% [markdown]
# Seeing some sample images

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img_dir = r"C:\Users\abhil\Desktop\skin disease\skin-disease-datasaet\train_set\BA- cellulitis\BA- cellulitis (1).jpeg"
img = mpimg.imread(img_dir)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
print(img.shape)
# Out:
# (224, 224, 3)

# %% [markdown]
# Using Data Generators  - Helping in Data Augmentation

# %%
#DEFINING THE DATA GENERATOR
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_gen = ImageDataGenerator(
    rescale = 1./255,
)

# %%
#Defining the training set data generator

train_dir  =r"C:\Users\abhil\Desktop\skin disease\skin-disease-datasaet\train_set"

train_generator = data_gen.flow_from_directory(
    train_dir,
    target_size =(150, 150),
    class_mode="categorical",
    batch_size = 32
)
# Out:
# Found 924 images belonging to 8 classes.

# %%
#Defining the test set generator

test_dir = r"C:\Users\abhil\Desktop\skin disease\skin-disease-datasaet\test_set"

test_generator = data_gen.flow_from_directory(
    test_dir,
    target_size = (150,150),
    class_mode="categorical",
    batch_size = 32
)
# Out:
# Found 233 images belonging to 8 classes.

# %% [markdown]
# Building the CNN

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))



model.add(Conv2D(128, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(512, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(512, (3,3), activation="relu", input_shape =(150, 150,3), padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.6))
model.add(Dense(128, activation ="relu"))
model.add(Dropout(0.6))
model.add(Dense(8, activation="softmax"))
# Out:
# c:\Users\abhil\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 75, 75, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 37, 37, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 37, 37, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 18, 18, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 18, 18, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 9, 9, 512)      │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 9, 9, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 4, 4, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,312,264 (16.45 MB)
#  Trainable params: 4,309,512 (16.44 MB)
#  Non-trainable params: 2,752 (10.75 KB)

# %% [markdown]
# Model Compiling

# %%
from keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Model Training

# %%
history  = model.fit(train_generator, epochs = 50, batch_size = 15, validation_data = test_generator)
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 485ms/step - accuracy: 0.1607 - loss: 4.8111 - val_accuracy: 0.1459 - val_loss: 2.1452
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 12s 421ms/step - accuracy: 0.2635 - loss: 2.7189 - val_accuracy: 0.1459 - val_loss: 2.3599
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 12s 419ms/step - accuracy: 0.3615 - loss: 2.0284 - val_accuracy: 0.0987 - val_loss: 2.5726
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 443ms/step - accuracy: 0.3845 - loss: 1.8200 - val_accuracy: 0.0987 - val_loss: 2.8527
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 447ms/step - accuracy: 0.4424 - loss: 1.6301 - val_accuracy: 0.0987 - val_loss: 2.9463
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 451ms/step - accuracy: 0.4896 - loss: 1.4098 - val_accuracy: 0.0987 - val_loss: 3.2882
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 456ms/step - accuracy: 0.4881 - loss: 1.4187 - val_accuracy: 0.0987 - val_loss: 3.5412
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5755 - loss: 1.1849 - val_accuracy: 0.0987 - val_loss: 3.5937
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 681ms/step - accuracy: 0.5920 - loss: 1.2020 - val_accuracy: 0.0987 - val_loss: 3.7836
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 761ms/step - accuracy: 0.6659 - loss: 1.0403 - val_accuracy: 0.0987 - val_loss: 4.2372
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 762ms/step - accuracy: 0.6618 - loss: 0.9735 - val_accuracy: 0.0987 - val_loss: 4.2791
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 659ms/step - accuracy: 0.6700 - loss: 0.8833 - val_accuracy: 0.1202 - val_loss: 3.4619
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 668ms/step - accuracy: 0.7320 - loss: 0.7754 - val_accuracy: 0.1545 - val_loss: 3.0044
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 669ms/step - accuracy: 0.7629 - loss: 0.6877 - val_accuracy: 0.1502 - val_loss: 2.9084
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 670ms/step - accuracy: 0.7060 - loss: 0.8242 - val_accuracy: 0.2704 - val_loss: 2.2681
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 690ms/step - accuracy: 0.7483 - loss: 0.6826 - val_accuracy: 0.3262 - val_loss: 2.1691
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 674ms/step - accuracy: 0.7691 - loss: 0.6933 - val_accuracy: 0.4721 - val_loss: 1.6855
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 664ms/step - accuracy: 0.7998 - loss: 0.5706 - val_accuracy: 0.5279 - val_loss: 1.4296
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 662ms/step - accuracy: 0.8117 - loss: 0.5143 - val_accuracy: 0.6052 - val_loss: 1.1921
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 682ms/step - accuracy: 0.8113 - loss: 0.5311 - val_accuracy: 0.6910 - val_loss: 1.0642
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 668ms/step - accuracy: 0.8271 - loss: 0.5078 - val_accuracy: 0.7554 - val_loss: 0.8667
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 678ms/step - accuracy: 0.8489 - loss: 0.4550 - val_accuracy: 0.7854 - val_loss: 0.6955
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 699ms/step - accuracy: 0.8471 - loss: 0.4284 - val_accuracy: 0.7597 - val_loss: 0.7135
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 657ms/step - accuracy: 0.8709 - loss: 0.3821 - val_accuracy: 0.8026 - val_loss: 0.5903
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 658ms/step - accuracy: 0.8850 - loss: 0.3270 - val_accuracy: 0.8155 - val_loss: 0.5139
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 655ms/step - accuracy: 0.8729 - loss: 0.3682 - val_accuracy: 0.8197 - val_loss: 0.5155
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 660ms/step - accuracy: 0.8934 - loss: 0.2981 - val_accuracy: 0.8112 - val_loss: 0.5628
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 664ms/step - accuracy: 0.8924 - loss: 0.3112 - val_accuracy: 0.8412 - val_loss: 0.4941
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 655ms/step - accuracy: 0.8715 - loss: 0.3642 - val_accuracy: 0.8026 - val_loss: 0.6260
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 653ms/step - accuracy: 0.8917 - loss: 0.3107 - val_accuracy: 0.8283 - val_loss: 0.5320
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 665ms/step - accuracy: 0.8953 - loss: 0.2852 - val_accuracy: 0.8455 - val_loss: 0.5690
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 707ms/step - accuracy: 0.9056 - loss: 0.2795 - val_accuracy: 0.8326 - val_loss: 0.5215
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 659ms/step - accuracy: 0.9262 - loss: 0.2412 - val_accuracy: 0.8412 - val_loss: 0.5151
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 668ms/step - accuracy: 0.9384 - loss: 0.1934 - val_accuracy: 0.8326 - val_loss: 0.5410
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 652ms/step - accuracy: 0.9425 - loss: 0.1907 - val_accuracy: 0.8155 - val_loss: 0.5705
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 651ms/step - accuracy: 0.9274 - loss: 0.2040 - val_accuracy: 0.8283 - val_loss: 0.5652
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 653ms/step - accuracy: 0.9267 - loss: 0.1913 - val_accuracy: 0.8369 - val_loss: 0.5551
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 663ms/step - accuracy: 0.9328 - loss: 0.1616 - val_accuracy: 0.8326 - val_loss: 0.5332
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 663ms/step - accuracy: 0.9362 - loss: 0.1904 - val_accuracy: 0.8369 - val_loss: 0.6008
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 670ms/step - accuracy: 0.9597 - loss: 0.1403 - val_accuracy: 0.8240 - val_loss: 0.6134
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 668ms/step - accuracy: 0.9577 - loss: 0.1305 - val_accuracy: 0.8455 - val_loss: 0.5545
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 660ms/step - accuracy: 0.9517 - loss: 0.1516 - val_accuracy: 0.8283 - val_loss: 0.6209
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 684ms/step - accuracy: 0.9376 - loss: 0.1900 - val_accuracy: 0.8369 - val_loss: 0.5601
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 676ms/step - accuracy: 0.9665 - loss: 0.0987 - val_accuracy: 0.8541 - val_loss: 0.4957
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 665ms/step - accuracy: 0.9550 - loss: 0.1166 - val_accuracy: 0.8541 - val_loss: 0.4967
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 666ms/step - accuracy: 0.9604 - loss: 0.1308 - val_accuracy: 0.8584 - val_loss: 0.4612
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 687ms/step - accuracy: 0.9672 - loss: 0.1051 - val_accuracy: 0.8627 - val_loss: 0.4586
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 667ms/step - accuracy: 0.9664 - loss: 0.1107 - val_accuracy: 0.8627 - val_loss: 0.4526
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 670ms/step - accuracy: 0.9602 - loss: 0.0913 - val_accuracy: 0.8627 - val_loss: 0.5376
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 670ms/step - accuracy: 0.9515 - loss: 0.1153 - val_accuracy: 0.7811 - val_loss: 0.8162

# %%
h = history

plt.plot(h.history["accuracy"])
plt.plot(h.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# %%
model.save("skin_disease_model.keras")
